# %%
# !python main.py --dataset 'aclImdb' --train_size 1 --epochs 500 --test_size 1.0
# !python main.py --dataset 'R8' --train_size 1 --epochs 500 --test_size 1.0
# !python main.py --dataset 'R8A' --train_size 1 --epochs 500 --test_size 1.0
# !python main.py --dataset 'R52' --train_size 1 --epochs 500 --test_size 1.0
# !python main.py --dataset 'ag_news' --train_size 0.5 --epochs 500 --test_size 1.0
